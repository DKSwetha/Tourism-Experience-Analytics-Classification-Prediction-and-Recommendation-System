# %% [markdown]
# # **Feature Engineering-**

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

master_df = pd.read_csv("../data/processed/master_cleaned.csv")

print(master_df.shape)
master_df.head()
# Out:
# (52890, 19)
#    TransactionId  UserId  VisitYear  VisitMonth  AttractionId  Rating  \
# 0              3   70456       2022          10           640       5
# 1              8    7567       2022          10           640       5
# 2              9   79069       2022          10           640       5
# 3             10   31019       2022          10           640       3
# 4             15   43611       2022          10           640       3
#
#   VisitMode  ContinentId  RegionId  CountryId  CityId    CityName  \
# 0   Couples          5.0      21.0      163.0  4341.0   Guildford
# 1   Friends          2.0       8.0       48.0   464.0     Ontario
# 2    Family          2.0       9.0       54.0   774.0      Brazil
# 3    Family          5.0      17.0      135.0   583.0      Zurich
# 4   Couples          5.0      21.0      163.0  1396.0  Manchester
#
#           Country            Region Continent  AttractionCityId  \
# 0  United Kingdom    Western Europe    Europe                 1
# 1          Canada  Northern America   America                 1
# 2          Brazil     South America   America                 1
# 3     Switzerland    Central Europe    Europe                 1
# 4  United Kingdom    Western Europe    Europe                 1
#
#             AttractionType                      Attraction  \
# 0  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
# 1  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
# 2  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
# 3  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
# 4  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
#
#                          AttractionAddress
# 0  Jl. Monkey Forest, Ubud 80571 Indonesia
# 1  Jl. Monkey Forest, Ubud 80571 Indonesia
# 2  Jl. Monkey Forest, Ubud 80571 Indonesia
# 3  Jl. Monkey Forest, Ubud 80571 Indonesia
# 4  Jl. Monkey Forest, Ubud 80571 Indonesia

# %% [markdown]
# Time-Based Features

# %%
# VisitDate
master_df['VisitDate'] = pd.to_datetime(
    master_df['VisitYear'].astype(str) + '-' +
    master_df['VisitMonth'].astype(str) + '-01'
)

# %%
# Quarter
master_df['Quarter'] = master_df['VisitDate'].dt.quarter

# %%
# Season
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Autumn'

master_df['Season'] = master_df['VisitMonth'].apply(get_season)

# %% [markdown]
# User-Level Features

# %%
# Total Visits
user_visits = master_df.groupby('UserId')['TransactionId'].count().reset_index()
user_visits.columns = ['UserId', 'User_Total_Visits']

master_df = master_df.merge(user_visits, on='UserId', how='left')

# %%
# Average Rating
user_avg_rating = master_df.groupby('UserId')['Rating'].mean().reset_index()
user_avg_rating.columns = ['UserId', 'User_Avg_Rating']

master_df = master_df.merge(user_avg_rating, on='UserId', how='left')

# %% [markdown]
# Attraction-Level Features

# %%
# Attraction Popularity
attraction_popularity = master_df.groupby('AttractionId')['TransactionId'].count().reset_index()
attraction_popularity.columns = ['AttractionId', 'Attraction_Popularity']

master_df = master_df.merge(attraction_popularity, on='AttractionId', how='left')

# %%
# Attraction Average Rating
attraction_avg_rating = master_df.groupby('AttractionId')['Rating'].mean().reset_index()
attraction_avg_rating.columns = ['AttractionId', 'Attraction_Avg_Rating']

master_df = master_df.merge(attraction_avg_rating, on='AttractionId', how='left')

# %% [markdown]
# Behavioral Feature

# %%
# User Preferred Attraction Type
user_fav_type = (
    master_df.groupby(['UserId', 'AttractionType'])['TransactionId']
    .count()
    .reset_index()
)

user_fav_type = user_fav_type.loc[
    user_fav_type.groupby('UserId')['TransactionId'].idxmax()
]

user_fav_type = user_fav_type[['UserId', 'AttractionType']]
user_fav_type.columns = ['UserId', 'User_Favorite_Type']

master_df = master_df.merge(user_fav_type, on='UserId', how='left')

# %%
master_df.head()
# Out:
#    TransactionId  UserId  VisitYear  VisitMonth  AttractionId  Rating  \
# 0              3   70456       2022          10           640       5
# 1              8    7567       2022          10           640       5
# 2              9   79069       2022          10           640       5
# 3             10   31019       2022          10           640       3
# 4             15   43611       2022          10           640       3
#
#   VisitMode  ContinentId  RegionId  CountryId  CityId    CityName  \
# 0   Couples          5.0      21.0      163.0  4341.0   Guildford
# 1   Friends          2.0       8.0       48.0   464.0     Ontario
# 2    Family          2.0       9.0       54.0   774.0      Brazil
# 3    Family          5.0      17.0      135.0   583.0      Zurich
# 4   Couples          5.0      21.0      163.0  1396.0  Manchester
#
#           Country            Region Continent  AttractionCityId  \
# 0  United Kingdom    Western Europe    Europe                 1
# 1          Canada  Northern America   America                 1
# 2          Brazil     South America   America                 1
# 3     Switzerland    Central Europe    Europe                 1
# 4  United Kingdom    Western Europe    Europe                 1
#
#             AttractionType                      Attraction  \
# 0  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
# 1  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
# 2  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
# 3  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
# 4  Nature & Wildlife Areas  Sacred Monkey Forest Sanctuary
#
#                          AttractionAddress  VisitDate  Quarter  Season  \
# 0  Jl. Monkey Forest, Ubud 80571 Indonesia 2022-10-01        4  Autumn
# 1  Jl. Monkey Forest, Ubud 80571 Indonesia 2022-10-01        4  Autumn
# 2  Jl. Monkey Forest, Ubud 80571 Indonesia 2022-10-01        4  Autumn
# 3  Jl. Monkey Forest, Ubud 80571 Indonesia 2022-10-01        4  Autumn
# 4  Jl. Monkey Forest, Ubud 80571 Indonesia 2022-10-01        4  Autumn
#
#    User_Total_Visits  User_Avg_Rating  Attraction_Popularity  \
# 0                  1              5.0                  13192
# 1                  1              5.0                  13192
# 2                  1              5.0                  13192
# 3                  2              3.0                  13192
# 4                  3              3.0                  13192
#
#    Attraction_Avg_Rating       User_Favorite_Type
# 0               4.267207  Nature & Wildlife Areas
# 1               4.267207  Nature & Wildlife Areas
# 2               4.267207  Nature & Wildlife Areas
# 3               4.267207  Nature & Wildlife Areas
# 4               4.267207  Nature & Wildlife Areas

# %% [markdown]
# Encoding Categorical Variables

# %%
model_df = master_df.copy()

# %%
categorical_cols = [
    'VisitMode',
    'Season',
    'Continent',
    'AttractionType',
    'User_Favorite_Type'
]

model_df = pd.get_dummies(model_df, columns=categorical_cols, drop_first=True)

# %% [markdown]
# Select Numerical Features

# %%
numerical_cols = [
    'VisitMonth',
    'VisitYear',
    'User_Total_Visits',
    'User_Avg_Rating',
    'Attraction_Popularity',
    'Attraction_Avg_Rating'
]

# %% [markdown]
# Scaling (Normalization)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

model_df[numerical_cols] = scaler.fit_transform(model_df[numerical_cols])

# %% [markdown]
# Final Model Dataset

# %%
model_df = model_df.drop(columns=[
    'TransactionId',
    'UserId',
    'AttractionId',
    'VisitDate',
    'CityName',
    'Country',
    'Region',
    'Attraction',
    'AttractionAddress'
])

# %%
model_df.head()
# Out:
#    VisitYear  VisitMonth  Rating  ContinentId  RegionId  CountryId  CityId  \
# 0   3.258693    0.992612       5          5.0      21.0      163.0  4341.0
# 1   3.258693    0.992612       5          2.0       8.0       48.0   464.0
# 2   3.258693    0.992612       5          2.0       9.0       54.0   774.0
# 3   3.258693    0.992612       3          5.0      17.0      135.0   583.0
# 4   3.258693    0.992612       3          5.0      21.0      163.0  1396.0
#
#    AttractionCityId  Quarter  User_Total_Visits  User_Avg_Rating  \
# 0                 1        4          -0.484049         1.016263
# 1                 1        4          -0.484049         1.016263
# 2                 1        4          -0.484049         1.016263
# 3                 1        4          -0.195395        -1.397088
# 4                 1        4           0.093260        -1.397088
#
#    Attraction_Popularity  Attraction_Avg_Rating  VisitMode_Couples  \
# 0               1.613029               0.373286               True
# 1               1.613029               0.373286              False
# 2               1.613029               0.373286              False
# 3               1.613029               0.373286              False
# 4               1.613029               0.373286               True
#
#    VisitMode_Family  VisitMode_Friends  VisitMode_Solo  Season_Spring  \
# 0             False              False           False          False
# 1             False               True           False          False
# 2              True              False           False          False
# 3              True              False           False          False
# 4             False              False           False          False
#
#    Season_Summer  Season_Winter  Continent_America  Continent_Asia  \
# 0          False          False              False           False
# 1          False          False               True           False
# 2          False          False               True           False
# 3          False          False              False           False
# 4          False          False              False           False
#
#    Continent_Australia & Oceania  Continent_Europe  AttractionType_Ballets  \
# 0                          False              True                   False
# 1                          False             False                   False
# 2                          False             False                   False
# 3                          False              True                   False
# 4                          False              True                   False
#
#    AttractionType_Beaches  AttractionType_Caverns & Caves  \
# 0                   False                           False
# 1                   False                           False
# 2                   False                           False
# 3                   False                           False
# 4                   False                           False
#
#    AttractionType_Flea & Street Markets  AttractionType_Historic Sites  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                          False
#
#    AttractionType_History Museums  AttractionType_National Parks  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False
#
#    AttractionType_Nature & Wildlife Areas  AttractionType_Neighborhoods  \
# 0                                    True                         False
# 1                                    True                         False
# 2                                    True                         False
# 3                                    True                         False
# 4                                    True                         False
#
#    AttractionType_Points Of Interest & Landmarks  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    AttractionType_Religious Sites  AttractionType_Spas  \
# 0                           False                False
# 1                           False                False
# 2                           False                False
# 3                           False                False
# 4                           False                False
#
#    AttractionType_Speciality Museums  AttractionType_Volcanos  \
# 0                              False                    False
# 1                              False                    False
# 2                              False                    False
# 3                              False                    False
# 4                              False                    False
#
#    AttractionType_Water Parks  AttractionType_Waterfalls  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    User_Favorite_Type_Ballets  User_Favorite_Type_Beaches  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    User_Favorite_Type_Caverns & Caves  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#    User_Favorite_Type_Flea & Street Markets  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    User_Favorite_Type_Historic Sites  User_Favorite_Type_History Museums  \
# 0                              False                               False
# 1                              False                               False
# 2                              False                               False
# 3                              False                               False
# 4                              False                               False
#
#    User_Favorite_Type_National Parks  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    User_Favorite_Type_Nature & Wildlife Areas  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
#
#    User_Favorite_Type_Neighborhoods  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    User_Favorite_Type_Points Of Interest & Landmarks  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    User_Favorite_Type_Religious Sites  User_Favorite_Type_Spas  \
# 0                               False                    False
# 1                               False                    False
# 2                               False                    False
# 3                               False                    False
# 4                               False                    False
#
#    User_Favorite_Type_Speciality Museums  User_Favorite_Type_Volcanos  \
# 0                                  False                        False
# 1                                  False                        False
# 2                                  False                        False
# 3                                  False                        False
# 4                                  False                        False
#
#    User_Favorite_Type_Water Parks  User_Favorite_Type_Waterfalls
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False

# %%
print(model_df.shape)
print(model_df.isnull().sum().sum())
# Out:
# (52890, 56)
# 0

# %%
import os

# Create processed folder if not exists
os.makedirs("../data/processed", exist_ok=True)

# Save model-ready dataset
model_df.to_csv("../data/processed/model_ready.csv", index=False)

print("Saved successfully!")
# Out:
# Saved successfully!
